# %%
# %matplotlib inline
import requests
import json
import ast
import string
import pandas as pd
import pymongo
from random import randint
import re
import numpy as np
import matplotlib.pyplot as plt
from datetime import date

# %%
job_categories = ["administrative-support",                    #01done
                  "audio-video-photography-production",        #02done
                 "business-merchant-development",              #03done
                 "business-intelligence",                      #04done
                 "buying-planning-instock-management",         #05done
                 "customer-service",                           #06done
                 "data-science",                               #07done
                 "database-administration",                    #08done
                 "design",                                     #09done
                 "economics",                                  #10done
                 "editorial-writing-content-management",       #11done
                 "facilities-maintenance-real-estate",         #12done
                 "finance-accounting",                         #13done
                 "fulfillment-operations-management",
                 "fulfillment-warehouse-associate",
                 "hardware-development",
                 "human-resources",                            #17done
                 "investigation-loss-prevention",
                 "leadership-development-training",
                 "legal",
                 "machine-learning-science",                   #21done
                 "marketing-pr",
                 "medical-health-safety",
                 "operations-it-support-engineering",          #24done
                 "project-program-product-management-non-tech",#25done
                 "public-policy",
                 "research-science",                           #27done
                 "sales-advertising-account-management",
                 "software-development",                      #29done
                 "solutions-architect",                        #30done
                 "supply-chain-transportation-management",     #31done
                 "systems-quality-security-engineering",       #32done
                 "project-program-product-management-technical"] #33done

# %%
added_stop_words = ["year","field","ability","related","using","employer","gender","equal","minority","sexual",\
                  "orientation","work","amazon","disability","concept","skill","language","team","tool","working",\
                  "building","highly","applied","problem","deep","including","presentation","equivalent","identity",\
                   "environment","relevant","track","set","strong","requirement","development","similar","role",\
                   "similar","big","verbal","large","result","model","knowledge","degree","complex","math","written",\
                   "excellent","able","abovementioned","academic", "female", "woman", "효율성", "aaa", "aac", "aap",\
                   "abathengi", "abb", "aber", "abgeschlossen", "ｉｔサービスマネジメントやｉｔビジネス運用等の経験",\
                   "ab", "abap", "abaqus", "ｉｔインフラの運用", "후보자는", "abgeschlossene", "abgeschlossenes", "abilità",\
                   "회의", "회의의", "효과적으로", "효율성등을", "효율적인", "ablility", "abschlussqualifikation", "화이트보딩",\
                   "환경의", "후보자", "abnormality", "aa", "aaai", "abahlukahlukileyo", "효율적으로", "활용한", "혹은",\
                   "aability", "환경에서", "현장", "aafa", "aat", "abgeschlossenem", "abgeschlossenem", "환경에서", "효과적인",\
                   "abhängig", "행사에서의", "현대", "현업", "현지", "협업을", "os", "support", "notwendige",'qualifikationen',\
  'abgeschlossene','kaufmännische','berufsausbildung','oder','relevante','berufserfahrung','bevorzugt','der',\
  'sachbearbeitung','mit','ausreichender','berufserfahrung','gleicher','bzw','ähnlicher','position','sehr','gute',\
  'kommunikations','und','konfliktfähigkeit','sowie','ausgeprägte','kundenorientierung','selbstständige','und',\
  'sorgfältige','arbeitsweise','sowie','ein','ausgeprägtes','organisationstalent','ausgeprägte','teamfähigkeit',\
  'und','hohe','serviceorientierung','sehr','gute','pckenntnisse','vorzugsweise','ms','office','insbesondere','sehr',\
  'gute','excelkenntnisse','begeisterung','im','umgang','mit','verschiedenen','und','neuen','systemen','gute',\
  'englischkenntnisse','wünschenswerte','qualifikationen','mindestens','jahr','erfahrung','gerne','einer',\
  'teamleiterfunktion','eines','operativen','bereiches','vorerfahrungen','im','bereich','der','personalsachbearbeitung',\
  'sind','sie','interessiert','wir','freuen','uns','darauf','von','ihnen','zu','hören','bitte','bewerben',\
  'sie','sich','unter','angabe','der','jobnummer','über','den','bewerberbutton','auf','unserer','website',\
  'sollten','die','bewerbungsunterlagen','nicht','vollständig','sein','anschreiben','lebenslauf','können','wir',\
  'ihre','bewerbung','leider','nicht','berücksichtigen','wir','wissen','dass','es','ihnen','wichtig','ist','wie',\
  'wir','ihre', 'persönlichen', 'daten', 'nutzen', 'und', 'schätzen', 'ihr', 'vertrauen', 'uns', 'dass', 'wir',\
  'diese','sorgfältig','und','gewissenhaft','behandeln','bitte','informieren','sie','sich','unserer','datenschutzerklärung',\
  'https','wwwamazonjobs','de','privacy','eu','um','mehr','darüber','zu','erfahren','wie','wir','personenbezogene',\
  'daten','unserer','bewerber','erheben','nutzen','und','übermitteln','amazon','ist','ein','arbeitgeber','der',\
  'chancengleichheit','fördert','und','fördermaßnahmen','zugunsten','benachteiligter','gruppen','bietet',"basic",\
    "qualifications","experience", "of", "years", "ea", "pa", "assistant", "given", "time", "assisting", "pc",\
    "computing", "located","mündlich", "schriftlich", "significance", "quantity","midcareer","considerably",\
    "portfolio", "yearround", "thoughtprovoking","nation","given","etre","older","time frequently", "older stand",\
    "employee issue", "classroom","localized", "instructional","adult","region site","legal","emergency","safety",\
    "specifically", "assumption","program","schedule","personal level","modern","design","science fundamental",\
    "software","professional software","ｉｔインフラの運用","ｉｔサービスマネジメントやｉｔビジネス運用等の経験","행사에서",\
    "solving","opportunity","skill","bachelor","service","age","understanding","proven","one","meet","etc",\
    "opportunityaffirmative","メール","everpositive","diary","person","quota","busdevemea","useful","教育レベル",\
    "einbringen","umfeldes","arbeitsumfeldes","problemlösungsfähigkeit","familiarizing","fixedterm","strongly",\
    "econometrics","encouraged background","strongly encouraged","task previous","adventure","completed","pride",\
    "walk","nicely","extended","reasonable","frequently","avoir","gone","gone volume","hourly","employee",\
    "wicklanderzulawski","demonstrate sound","conference","american","understandable","xpress","chef","new current",\
    "チャネル管理の経験","年以上の業務委託先が配送する物流業務の管理","preferred","well","based","action","requirement",\
    "demonstrated","effectively","level","across","humidity","new","ability","requirements","abilities","providing",\
    "least","holiday","holdiays","high"]

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.jobs
collection = db.roles

# %%
#FETCHING DATA
arr = []
category_list = []
i = 0
for obj in collection.find():
    arr.append([obj["category"], obj["Basic_Qualif"],obj["Preferred_Qualif"]])

for category in collection.find().distinct('category'):
    category_list.append([category, i])
    i+=1

# %%
#BALANCE DATA
arrB = []
for obj in collection.find():
    j = 0
    
#     aux.append(obj["category"])
    arr.append([obj["category"], obj["Basic_Qualif"],obj["Preferred_Qualif"]])

# %% [markdown]
# NLP Processing

# %%
processed_arr = []
for roleD in arr:
    
    if roleD[2] == None:
        qualif = roleD[1]
    else:
        qualif = roleD[1] + " " + roleD[2]
    
    qualif = re.sub("\<.*?\>", " ", qualif)                              #Remove tags
    qualif = re.sub("/", " ", qualif)                                    #Remove /
    qualif = qualif.translate(str.maketrans('', '', string.punctuation)) #Remove punctuation
    qualif = re.sub("·", "", qualif)                                     #Remove periods
    qualif = ''.join(c for c in qualif if not c.isdigit())               #Remove numbers
    qualif = qualif.lower()                                              #Turn to lowercase
    processed_arr.append([roleD[0], qualif])

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
# from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
# from autocorrect import Speller

wordnet_lemmatizer = WordNetLemmatizer()
# snowball_stemmer = SnowballStemmer("english")

stopWords = stopwords.words('english')

# stopwords = stopwords.words('english')
stopWords += added_stop_words
stopWords.extend(added_stop_words)

ready_arr = []
for role_qual in processed_arr:
    clean_word_list = [word for word in role_qual[1].split() if word not in stopWords]
    cleaner_list = [word for word in clean_word_list if word not in added_stop_words]
    lemmatized_word = [wordnet_lemmatizer.lemmatize(word) for word in cleaner_list]
    cleaner_list2 = [word for word in lemmatized_word if word not in added_stop_words]
    role_Q = " ".join(cleaner_list2)
    ready_arr.append([role_qual[0], role_Q])
# Out:
# [nltk_data] Downloading package punkt to /Users/marian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/marian/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/marian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
d_Frame = pd.DataFrame.from_records(ready_arr, columns = ["category", "Qualif"])
unique_cat = pd.DataFrame(category_list, columns=["category", "category_id"])
d_FR = pd.merge(d_Frame, unique_cat, on = "category")

# %%
d_FR.head()
# Out:
#                  category                                             Qualif  \
# 0  Administrative Support  executive hr travel agent administrative coord...
# 1  Administrative Support
# 2  Administrative Support  executive assistance project management design...
# 3  Administrative Support  executive microsoft outlook word excel handlin...
# 4  Administrative Support  five executive prioritize handle multiple assi...
#
#    category_id
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
category_to_id = dict(unique_cat.values)
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(d_FR.Qualif).toarray()
labels = d_FR.category_id
features.shape
# Out:
# (66580, 126928)

# %%
from sklearn.feature_selection import chi2
freq_words = {}
freq_list = []
N = 10
for Product, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    
    freq_words["Categ"] = Product
    freq_words["unigr"] = unigrams[-N:]
    freq_words["bigra"] = bigrams[-N:]
    freq_list.append(freq_words.copy())
    print("# '{}':".format(Product))
#     print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
#     print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))

# %%
freq_list
# Out:
# [{'Categ': 'Administrative Support',
#   'unigr': ['メール',
#    'adequately',
#    'word',
#    'administrative',
#    'getitdone',
#    'calendar',
#    'outlook',
#    'impeccable',
#    'integrity',
#    'discretion'],
#   'bigra': ['discretion impeccable',
#    'microsoft outlook',
#    'integrity discretion',
#    'assignment high',
#    'individual minimal',
#    'motivated organized',
#    'analytical improve',
#    'word management',
#    'prioritize handle',
#    'multiple assignment']},
#  {'Categ': 'Audio / Video / Photography Production',
#   'unigr': ['unscripted',
#    'onfigure',
#    'intensity',
#    'producer',
#    'lighting',
#    'onset',
#    'studio',
#    'productivityfocused',
#    'photography',
#    'styling'],
#   'bigra': ['mac platform',
#    'communicate creative',
#    'productivityfocused quick',
#    'commercial photography',
#    'quick solver',
#    'workflow prioritization',
#    'volume workflow',
#    'delegation tight',
#    'obsession delighting',
#    'commercial studio']},
#  {'Categ': 'Business & Merchant Development',
#   'unigr': ['partner',
#    'isv',
#    'joint',
#    'sale',
#    'key',
#    'gtm',
#    'alliance',
#    'hosted',
#    'selling',
#    'corp'],
#   'bigra': ['management selling',
#    'key performance',
#    'analytical turn',
#    'exceeds key',
#    'corp preference',
#    'turn detailed',
#    'strategic insight',
#    'aws corp',
#    'leadership internal',
#    'organization key']},
#  {'Categ': 'Business Intelligence',
#   'unigr': ['analyst',
#    'bi',
#    'datasets',
#    'quicksight',
#    'statistic',
#    'visualization',
#    'intelligence',
#    'redshift',
#    'etl',
#    'tableau'],
#   'bigra': ['largescale datasets',
#    'visualization tableau',
#    'modeling etl',
#    'data visualization',
#    'data modeling',
#    'sql etl',
#    'engineering statistic',
#    'data engineering',
#    'etl data',
#    'business intelligence']},
#  {'Categ': 'Buying, Planning, & Instock Management',
#   'unigr': ['ロジカルに考え',
#    'negotiating',
#    'category',
#    '教育レベル',
#    'negotiation',
#    'polished',
#    'retail',
#    'inventory',
#    'highenergy',
#    'buying'],
#   'bigra': ['communication speaking',
#    'highenergy fastpaced',
#    'negotiation pricing',
#    'think react',
#    'buying account',
#    'react highenergy',
#    'agility learn',
#    'learn webbased',
#    'aptitude agility',
#    'negotiating influencing']},
#  {'Categ': 'Customer Service',
#   'unigr': ['empathize',
#    'einarbeiten',
#    'decipher',
#    'escalated',
#    'diploma',
#    'laymen',
#    'instant',
#    'categorize',
#    'messenger',
#    'keyholder'],
#   'bigra': ['prior physical',
#    'diploma retail',
#    'physical store',
#    'facing device',
#    'store years',
#    'delivering veteran',
#    'key holder',
#    'facing retail',
#    'years retail',
#    'retail customer']},
#  {'Categ': 'Data Science',
#   'unigr': ['academicstyled',
#    'billion',
#    'extraction',
#    'row',
#    'matlab',
#    'interval',
#    'filtering',
#    'statistical',
#    'statistic',
#    'scientist'],
#   'bigra': ['sa matlab',
#    'querying sql',
#    'solution research',
#    'statistical mathematical',
#    'extraction analysis',
#    'quantitative modeling',
#    'advocate technical',
#    'scientist engineering',
#    'communication advocate',
#    'analytical involving']},
#  {'Categ': 'Database Administration',
#   'unigr': ['redshift',
#    'mssql',
#    'db',
#    'highlyoptimized',
#    'bom',
#    'backup',
#    'dba',
#    'parquet',
#    'administering',
#    'rac'],
#   'bigra': ['architecture configuration',
#    'requires operational',
#    'administering supporting',
#    'multiple oracle',
#    'configuration administration',
#    'available unix',
#    'planning addition',
#    'tuning backup',
#    'recovery scalability',
#    'scalability capacity']},
#  {'Categ': 'Design',
#   'unigr': ['illustrator',
#    'invision',
#    'visual',
#    'demonstrating',
#    'usercentered',
#    'sketch',
#    'humancomputer',
#    'interaction',
#    'hci',
#    'designer'],
#   'bigra': ['usercentered solution',
#    'developer implementation',
#    'sample demonstrating',
#    'user research',
#    'user designer',
#    'designer interaction',
#    'hci professional',
#    'interaction designer',
#    'interaction hci',
#    'humancomputer interaction']},
#  {'Categ': 'Economics',
#   'unigr': ['postphd',
#    'economics',
#    'postdoctoral',
#    'sawtooth',
#    'causal',
#    'economic',
#    'economist',
#    'econometric',
#    'encouraged',
#    'stata'],
#   'bigra': ['fastpaced business',
#    'methodology application',
#    'business research',
#    'statistic methodology',
#    'consulting government',
#    'encouraged background',
#    'applicant encouraged',
#    'government research',
#    'research record',
#    'phd economics']},
#  {'Categ': 'Editorial, Writing, & Content Management',
#   'unigr': ['voluminous',
#    'markup',
#    'taxonomy',
#    'content',
#    'fullyfunctional',
#    'philology',
#    'cat',
#    'journalism',
#    'proofreading',
#    'translation'],
#   'bigra': ['previous task',
#    'produce collaborate',
#    'translation interpreting',
#    'study translation',
#    'journalism public',
#    'task previous',
#    'preferably study',
#    'philology journalism',
#    'communication philology',
#    'technical writing']},
#  {'Categ': 'Facilities, Maintenance, & Real Estate',
#   'unigr': ['estate',
#    'maintenance',
#    'apprenticeship',
#    'oee',
#    'computerized',
#    'blueprint',
#    'plc',
#    'mhe',
#    'conveyor',
#    'cmms'],
#   'bigra': ['preventative maintenance',
#    'schematic reading',
#    'blueprint electrical',
#    'electronic principle',
#    'multi skilled',
#    'skilled electrical',
#    'mechanical discipline',
#    'industrial electrical',
#    'computerized maintenance',
#    'maintenance procedure']},
#  {'Categ': 'Finance & Accounting',
#   'unigr': ['budgeting',
#    'hoc',
#    'essbase',
#    'financial',
#    'variance',
#    'tax',
#    'cognos',
#    'cpa',
#    'finance',
#    'accounting'],
#   'bigra': ['combination education',
#    'master combination',
#    'variance analysis',
#    'economics analytical',
#    'analytical engineering',
#    'finance master',
#    'minimum finance',
#    'ba finance',
#    'accounting business',
#    'finance accounting']},
#  {'Categ': 'Fulfillment & Operations Management',
#   'unigr': ['relocate',
#    'assistance',
#    'season',
#    'kaizen',
#    'workable',
#    'hesitate',
#    'weekend',
#    'shift',
#    'holiday',
#    'volunteer'],
#   'bigra': ['available overtime',
#    'metric process',
#    'provide workable',
#    'assignment multiple',
#    'career assignment',
#    'engineering operation',
#    'longterm career',
#    'production distribution',
#    'management manufacturing',
#    'direct management']},
#  {'Categ': 'Fulfillment / Warehouse Associate',
#   'unigr': ['amont',
#    'assiduité',
#    'effets',
#    'aval',
#    'praca',
#    'komputerem',
#    'identifier',
#    'tap',
#    'bend',
#    'squat'],
#   'bigra': ['like double',
#    'accommodation veteran',
#    'bend reach',
#    'pull squat',
#    'squat bend',
#    'lb accommodation',
#    'reach lift',
#    'stand period',
#    'period push',
#    'candidate stand']},
#  {'Categ': 'Hardware Development',
#   'unigr': ['dfm',
#    'ofdm',
#    'microwave',
#    'spacecraft',
#    'cellular',
#    'circuit',
#    'analog',
#    'pcb',
#    'assembly',
#    'rf'],
#   'bigra': ['communication rf',
#    'rf engineering',
#    'rf standard',
#    'broadband wireless',
#    'mechanical engineering',
#    'wireless communication',
#    'product volume',
#    'communication engineering',
#    'volume production',
#    'electrical communication']},
#  {'Categ': 'Human Resources',
#   'unigr': ['leave',
#    'recruiting',
#    'hris',
#    'hrm',
#    'peoplesoft',
#    'postsecondary',
#    'resource',
#    'sourcing',
#    'human',
#    'hr'],
#   'bigra': ['strict confidentiality',
#    'workflow candidate',
#    'compensation package',
#    'competitive compensation',
#    'hiring manager',
#    'resource business',
#    'candidate hiring',
#    'supporting client',
#    'client group',
#    'human resource']},
#  {'Categ': 'Investigation & Loss Prevention',
#   'unigr': ['psp',
#    'olr',
#    'selfdisciplined',
#    'cpp',
#    'writtten',
#    'investigation',
#    'fraud',
#    'loss',
#    'reid',
#    'emergence'],
#   'bigra': ['advanced esp',
#    'selfdisciplined diligent',
#    'exceptional operational',
#    'commitment emergence',
#    'emergence world',
#    'world customercentric',
#    'managerial analytical',
#    'esp excel',
#    'operational managerial',
#    'loss prevention']},
#  {'Categ': 'Leadership Development & Training',
#   'unigr': ['scorm',
#    'edited',
#    'awstrainap',
#    'storyline',
#    'camtasia',
#    'lm',
#    'captivate',
#    'elearning',
#    'instructorled',
#    'training'],
#   'bigra': ['group professional',
#    'training content',
#    'driving bachelor',
#    'learning management',
#    'region site',
#    'manage learner',
#    'writing stage',
#    'infrastructure desired',
#    'stage presence',
#    'training material']},
#  {'Categ': 'Legal',
#   'unigr': ['firm',
#    'trademark',
#    'jd',
#    'challenged',
#    'admitted',
#    'law',
#    'attorney',
#    'paralegal',
#    'inhouse',
#    'drafting'],
#   'bigra': ['sense great',
#    'inhouse plus',
#    'law school',
#    'judgment ambiguous',
#    'demonstrate sound',
#    'private practice',
#    'state bar',
#    'firm inhouse',
#    'drafting negotiating',
#    'law firm']},
#  {'Categ': 'Machine Learning Science',
#   'unigr': ['phd',
#    'recognition',
#    'natural',
#    'publication',
#    'specialization',
#    'speech',
#    'journal',
#    'learning',
#    'scientific',
#    'machine'],
#   'bigra': ['phd machine',
#    'specialization speech',
#    'learning statistic',
#    'speech recognition',
#    'processing machine',
#    'statistic quantitative',
#    'mathematics specialization',
#    'recognition natural',
#    'machine learning',
#    'natural processing']},
#  {'Categ': 'Marketing & PR',
#   'unigr': ['merchandising',
#    'content',
#    'hightechnology',
#    'brand',
#    'digital',
#    'social',
#    'marketo',
#    'pr',
#    'campaign',
#    'marketing'],
#   'bigra': ['marketing automation',
#    'online marketing',
#    'marketing business',
#    'marketing strategy',
#    'independently autonomously',
#    'marketing communication',
#    'marketing marketing',
#    'marketing campaign',
#    'bachelor marketing',
#    'digital marketing']},
#  {'Categ': 'Medical, Health, & Safety',
#   'unigr': ['machinery',
#    'worker',
#    'hazard',
#    'osha',
#    'ergonomics',
#    'accident',
#    'ehs',
#    'cfr',
#    'cpr',
#    'environmental'],
#   'bigra': ['accident data',
#    'concern conduct',
#    'job hazard',
#    'implement department',
#    'department goal',
#    'worker compensation',
#    'aid cpr',
#    'day night',
#    'osha regulation',
#    'regulation cfr']},
#  {'Categ': 'Operations, IT, & Support Engineering',
#   'unigr': ['iperf',
#    'mechanical',
#    'fiber',
#    'ccna',
#    'tcp',
#    'ssl',
#    'copper',
#    'troubleshooting',
#    'cabling',
#    'cisco'],
#   'bigra': ['standard certification',
#    'stack custom',
#    'iperf mtr',
#    'linux administration',
#    'administration linux',
#    'copper fiber',
#    'tcp ip',
#    'cisco io',
#    'data center',
#    'networking dns']},
#  {'Categ': 'Project/Program/Product Management--Non-Tech',
#   'unigr': ['project',
#    'business',
#    'cross',
#    'chain',
#    'quantitative',
#    'supply',
#    'pmp',
#    'crossfunctional',
#    'stakeholder',
#    'mba'],
#   'bigra': ['supply chain',
#    'present information',
#    'physical retail',
#    'fraud compliance',
#    'discretion handle',
#    'quantitative use',
#    'analytical quantitative',
#    'data metric',
#    'project management',
#    'product management']},
#  {'Categ': 'Project/Program/Product Management--Technical',
#   'unigr': ['discus',
#    'effort',
#    'roadmap',
#    'shaping',
#    'followthrough',
#    'selfmotivate',
#    'conception',
#    'scope',
#    'coordinating',
#    'product'],
#   'bigra': ['manage tradeoff',
#    'technical project',
#    'technical manage',
#    'nontechnical individual',
#    'detailoriented selfmotivate',
#    'followthrough project',
#    'record detailoriented',
#    'selfmotivate followthrough',
#    'management industry',
#    'product management']},
#  {'Categ': 'Public Policy',
#   'unigr': ['talking',
#    'pertaining',
#    'lobbying',
#    'factual',
#    'strongest',
#    'ethical',
#    'intelligently',
#    'policymaking',
#    'political',
#    'legislative'],
#   'bigra': ['maintain highest',
#    'regulatory proposal',
#    'synthesize policy',
#    'public policy',
#    'confidentiality integrity',
#    'legislative regulatory',
#    'highest personal',
#    'personal ethical',
#    'conduct confidentiality',
#    'ethical conduct']},
#  {'Categ': 'Research Science',
#   'unigr': ['naturallanguage',
#    'mosel',
#    'peerreviewed',
#    'learning',
#    'ampl',
#    'matlab',
#    'phd',
#    'research',
#    'machine',
#    'publication'],
#   'bigra': ['mosel matlab',
#    'modeling ampl',
#    'independently diverse',
#    'learning phd',
#    'computer vision',
#    'python graduate',
#    'machine learning',
#    'physic machine',
#    'phd programming',
#    'phd operation']},
#  {'Categ': 'Sales, Advertising, & Account Management',
#   'unigr': ['awsjpsalesap',
#    'salesforcecom',
#    'target',
#    'advertising',
#    'prospecting',
#    'crm',
#    'mi',
#    'selling',
#    'account',
#    'sale'],
#   'bigra': ['direct enterprise',
#    'sale engineering',
#    'customer network',
#    'enterprise account',
#    'technical background',
#    'science mi',
#    'technology sale',
#    'sale business',
#    'background engineering',
#    'mi plus']},
#  {'Categ': 'Software Development',
#   'unigr': ['scaling',
#    'computer',
#    'pattern',
#    'reliability',
#    'programming',
#    'fundamental',
#    'structure',
#    'algorithm',
#    'java',
#    'objectoriented'],
#   'bigra': ['architecture architecture',
#    'professional programming',
#    'scaling current',
#    'reliability scaling',
#    'pattern reliability',
#    'contributing architecture',
#    'java objectoriented',
#    'data structure',
#    'programming java',
#    'science fundamental']},
#  {'Categ': 'Solutions Architect',
#   'unigr': ['transforming',
#    'devops',
#    'puppet',
#    'sap',
#    'hipaa',
#    'migrating',
#    'aws',
#    'architecting',
#    'enterprise',
#    'implementation'],
#   'bigra': ['adapt technology',
#    'puppet salt',
#    'migrating transforming',
#    'solution cloud',
#    'operating solution',
#    'aws variety',
#    'architecting operating',
#    'strategically business',
#    'high comfort',
#    'implementation consulting']},
#  {'Categ': 'Supply Chain/Transportation Management',
#   'unigr': ['amazonair',
#    '深夜勤務手当',
#    'hub',
#    'チャネル管理の経験',
#    '年以上の業務委託先が配送する物流業務の管理',
#    'carrier',
#    'transportation',
#    'chain',
#    'logistics',
#    'supply'],
#   'bigra': ['performance carrier',
#    'years conducting',
#    'chain mathematics',
#    'transportation forecasting',
#    'chain logistics',
#    'management transportation',
#    'logistics ecommerce',
#    'logistics delivery',
#    'delivery performance',
#    'supply chain']},
#  {'Categ': 'Systems, Quality, & Security Engineering',
#   'unigr': ['attack',
#    'security',
#    'cryptography',
#    'coverage',
#    'userlevel',
#    'threat',
#    'automation',
#    'vulnerability',
#    'test',
#    'qa'],
#   'bigra': ['test automation',
#    'creativity initiative',
#    'coverage effectiveness',
#    'communicating crossfunctionally',
#    'test plan',
#    'crossfunctionally management',
#    'informal setting',
#    'test execution',
#    'qa methodology',
#    'test case']}]

# %% [markdown]
# # ML

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier

# %%
# from sklearn.utils import resample
# from random import sample
# import random

# categ_list =d_FR["category_id"].to_list()
# num_occ = d_FR.groupby('category_id').count()

# for cat in num_occ["category_id"]:
#     print(cat)
# #     if cat > 300:
# #         sub_l.append(cat)

# df_majority_downsampled = resample(df_majority, 
#                                  replace=False,    # sample without replacement
#                                  n_samples=300,     # to match minority class
#                                  random_state=123)

# %%
from sklearn.model_selection import cross_val_score

CV = 5
count_vect = CountVectorizer()
tfidf_transformer = TfidfTransformer()

X_C = count_vect.fit_transform(d_FR['Qualif'])
X_CV = tfidf_transformer.fit_transform(X_C)
(cross_val_score(LinearSVC(), X_CV, d_FR['category'], cv = CV))
# Out:
# array([0.85662322, 0.8481723 , 0.83887623, 0.84052904, 0.84799148])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(d_FR['Qualif'], d_FR['category'], random_state = 0)
X_train_counts = count_vect.fit_transform(X_train)
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
model = LinearSVC()
cfl = model.fit(X_train_tfidf, y_train)

# %%
print(cfl.predict(count_vect.transform(["phd research"])))
# Out:
# ['Research Science']

# %%
y_pred = model.predict(count_vect.transform(X_test))
len(y_pred)
# Out:
# 8232

# %%
import seaborn as sns
# X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(d_FR['Qualif'], d_FR['category'], d_FR.index, test_size=0.33, random_state=0)
# X_T = count_vect.transform(X_train)
# model.fit(X_T, y_train)

from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels = unique_cat.category.values, yticklabels = unique_cat.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package punkt to /Users/marian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/marian/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
feat_names = count_vect.get_feature_names()

# %%
datax = count_vect.transform(d_FR["Qualif"].to_list())
dfF = pd.DataFrame(data = datax.toarray(), columns = feat_names)
dft = dfF.transpose()

# %%
dft.head()
# Out:
#               0      1      2      3      4      5      6      7      8      \
# abandon           0      0      0      0      0      0      0      0      0
# abilitatilor      0      0      0      0      0      0      0      0      0
# ability           0      0      0      0      0      0      0      0      0
# abitur            0      0      0      0      0      0      0      0      0
# able              0      0      0      0      0      0      0      0      0
#
#               9      ...  32916  32917  32918  32919  32920  32921  32922  \
# abandon           0  ...      0      0      0      0      0      0      0
# abilitatilor      0  ...      0      0      0      0      0      0      0
# ability           0  ...      0      0      0      0      0      0      0
# abitur            0  ...      0      0      0      0      0      0      0
# able              0  ...      0      0      0      0      0      0      0
#
#               32923  32924  32925
# abandon           0      0      0
# abilitatilor      0      0      0
# ability           0      0      0
# abitur            0      0      0
# able              0      0      0
#
# [5 rows x 32926 columns]

# %%
top_dict = {}
for c in dft.columns:
    top = dft[c].sort_values(ascending = False).head(50)
    top_dict[c] = list(zip(top.index, top.values))

# %%
from collections import Counter

words = []
for role in dft.columns:
    top = [word for (word, count) in top_dict[role]]
    for t in top:
        words.append(t)
        
moc = Counter(words).most_common()

# %%
moc
# Out:
# [('communication', 17840),
#  ('management', 16227),
#  ('science', 16023),
#  ('computer', 15063),
#  ('technical', 14347),
#  ('engineering', 13319),
#  ('system', 12220),
#  ('data', 11594),
#  ('project', 10968),
#  ('technology', 10945),
#  ('business', 10580),
#  ('customer', 9738),
#  ('bachelor', 9454),
#  ('java', 9292),
#  ('veteran', 8668),
#  ('analytical', 8366),
#  ('programming', 8125),
#  ('professional', 7869),
#  ('product', 7257),
#  ('process', 7159),
#  ('application', 7056),
#  ('operation', 7044),
#  ('analysis', 6988),
#  ('practice', 6684),
#  ('architecture', 6531),
#  ('high', 6416),
#  ('least', 6333),
#  ('solution', 6296),
#  ('record', 6281),
#  ('developing', 6231),
#  ('holiday', 5763),
#  ('holdiays', 5756),
#  ('industry', 5710),
#  ('holder', 5703),
#  ('holding', 5700),
#  ('managing', 5565),
#  ('multiple', 5522),
#  ('holddown', 5445),
#  ('hold', 5274),
#  ('holistic', 5227),
#  ('complexity', 5173),
#  ('python', 5093),
#  ('cloud', 5090),
#  ('algorithm', 5009),
#  ('distributed', 4875),
#  ('web', 4787),
#  ('hol', 4737),
#  ('holistically', 4707),
#  ('structure', 4591),
#  ('master', 4535),
#  ('aws', 4517),
#  ('mba', 4484),
#  ('sql', 4442),
#  ('hoja', 4410),
#  ('linux', 4328),
#  ('required', 4318),
#  ('excel', 4310),
#  ('proficiency', 4307),
#  ('information', 4287),
#  ('home', 4280),
#  ('drive', 4186),
#  ('fastpaced', 4116),
#  ('principle', 4064),
#  ('leadership', 4009),
#  ('best', 3982),
#  ('scale', 3970),
#  ('hohes', 3927),
#  ('performance', 3927),
#  ('fundamental', 3841),
#  ('english', 3819),
#  ('advanced', 3798),
#  ('passion', 3785),
#  ('source', 3727),
#  ('objectoriented', 3720),
#  ('functional', 3708),
#  ('security', 3689),
#  ('delivering', 3505),
#  ('hoher', 3492),
#  ('amazon', 3470),
#  ('agile', 3460),
#  ('homegrown', 3415),
#  ('company', 3396),
#  ('discipline', 3389),
#  ('background', 3375),
#  ('exceeds', 3355),
#  ('handson', 3266),
#  ('manage', 3234),
#  ('hohen', 3213),
#  ('code', 3196),
#  ('detail', 3163),
#  ('must', 3110),
#  ('standard', 3097),
#  ('full', 3074),
#  ('communicate', 3048),
#  ('ownership', 3037),
#  ('priority', 3034),
#  ('cycle', 3030),
#  ('implementation', 3023),
#  ('operating', 2992),
#  ('hoch', 2976),
#  ('communicating', 2968),
#  ('hoc', 2963),
#  ('learning', 2960),
#  ('control', 2942),
#  ('pattern', 2920),
#  ('enterprise', 2899),
#  ('writing', 2885),
#  ('database', 2850),
#  ('familiarity', 2834),
#  ('methodology', 2831),
#  ('plus', 2822),
#  ('hohem', 2812),
#  ('ambiguous', 2808),
#  ('engineer', 2791),
#  ('testing', 2779),
#  ('organization', 2773),
#  ('driving', 2773),
#  ('platform', 2769),
#  ('machine', 2761),
#  ('oral', 2757),
#  ('within', 2753),
#  ('hochdynamischen', 2751),
#  ('perl', 2724),
#  ('reliability', 2724),
#  ('infrastructure', 2718),
#  ('user', 2694),
#  ('external', 2687),
#  ('hobby', 2683),
#  ('attention', 2680),
#  ('homeoffice', 2676),
#  ('good', 2645),
#  ('sale', 2628),
#  ('operational', 2594),
#  ('build', 2593),
#  ('hochzuladen', 2569),
#  ('hochentwickelte', 2569),
#  ('eg', 2566),
#  ('metric', 2549),
#  ('fast', 2537),
#  ('largescale', 2527),
#  ('use', 2485),
#  ('delivery', 2465),
#  ('make', 2454),
#  ('develop', 2452),
#  ('quantitative', 2431),
#  ('scalable', 2429),
#  ('crossfunctional', 2422),
#  ('scaling', 2419),
#  ('interpersonal', 2417),
#  ('leading', 2417),
#  ('expertise', 2411),
#  ('hochzukrempeln', 2395),
#  ('life', 2364),
#  ('hochmotiviertes', 2358),
#  ('hob', 2314),
#  ('partner', 2302),
#  ('framework', 2283),
#  ('take', 2272),
#  ('feature', 2271),
#  ('developer', 2258),
#  ('internal', 2254),
#  ('improvement', 2243),
#  ('think', 2197),
#  ('ba', 2162),
#  ('amazoncom', 2155),
#  ('current', 2152),
#  ('mathematics', 2152),
#  ('stakeholder', 2145),
#  ('production', 2145),
#  ('analytics', 2144),
#  ('influence', 2144),
#  ('hochschul', 2137),
#  ('hochwertige', 2126),
#  ('consulting', 2125),
#  ('javascript', 2120),
#  ('audience', 2115),
#  ('candidate', 2112),
#  ('successfully', 2108),
#  ('phd', 2037),
#  ('implementing', 2034),
#  ('scripting', 2032),
#  ('goal', 2027),
#  ('decision', 2027),
#  ('deliver', 2023),
#  ('oriented', 2012),
#  ('hochspannungsschaltungen', 2002),
#  ('hochschulabschluss', 1998),
#  ('contributing', 1994),
#  ('homogeneous', 1966),
#  ('executive', 1960),
#  ('prior', 1953),
#  ('effective', 1950),
#  ('technique', 1938),
#  ('unix', 1933),
#  ('quickly', 1916),
#  ('exceptional', 1913),
#  ('finance', 1911),
#  ('ruby', 1890),
#  ('hochschulabsolventen', 1881),
#  ('hochschulstudium', 1872),
#  ('prioritize', 1864),
#  ('hoaiverträgen', 1856),
#  ('relationship', 1855),
#  ('manager', 1844),
#  ('paced', 1837),
#  ('networking', 1835),
#  ('success', 1834),
#  ('like', 1825),
#  ('minimum', 1824),
#  ('network', 1823),
#  ('years', 1821),
#  ('microsoft', 1813),
#  ('planning', 1810),
#  ('direct', 1810),
#  ('delivered', 1791),
#  ('hochschulreife', 1781),
#  ('competing', 1781),
#  ('statistic', 1781),
#  ('global', 1759),
#  ('coding', 1748),
#  ('depth', 1732),
#  ('deadline', 1731),
#  ('hochschule', 1730),
#  ('online', 1723),
#  ('dynamic', 1702),
#  ('judgment', 1685),
#  ('modeling', 1681),
#  ('automation', 1673),
#  ('research', 1668),
#  ('review', 1664),
#  ('reporting', 1660),
#  ('taking', 1660),
#  ('solid', 1648),
#  ('marketing', 1638),
#  ('excellence', 1637),
#  ('previous', 1627),
#  ('influencing', 1610),
#  ('server', 1589),
#  ('education', 1579),
#  ('posse', 1553),
#  ('strategy', 1548),
#  ('financial', 1541),
#  ('need', 1524),
#  ('approach', 1513),
#  ('troubleshooting', 1496),
#  ('area', 1456),
#  ('nontechnical', 1445),
#  ('protocol', 1444),
#  ('center', 1444),
#  ('solve', 1434),
#  ('risk', 1433),
#  ('quality', 1430),
#  ('achieve', 1427),
#  ('task', 1426),
#  ('hone', 1421),
#  ('administration', 1414),
#  ('plan', 1414),
#  ('designing', 1412),
#  ('understand', 1411),
#  ('available', 1407),
#  ('certification', 1397),
#  ('integration', 1394),
#  ('ho', 1393),
#  ('electrical', 1380),
#  ('organizational', 1379),
#  ('independently', 1377),
#  ('ambiguity', 1375),
#  ('senior', 1363),
#  ('continuous', 1360),
#  ('mentoring', 1360),
#  ('proficient', 1359),
#  ('mobile', 1355),
#  ('word', 1347),
#  ('noninternship', 1346),
#  ('ecommerce', 1344),
#  ('resource', 1332),
#  ('account', 1327),
#  ('ｏｓ', 1318),
#  ('maintain', 1311),
#  ('lead', 1309),
#  ('client', 1299),
#  ('oracle', 1289),
#  ('workforce', 1279),
#  ('change', 1275),
#  ('urgency', 1274),
#  ('tradeoff', 1274),
#  ('clear', 1266),
#  ('impact', 1265),
#  ('applicant', 1259),
#  ('devops', 1259),
#  ('passionately', 1254),
#  ('practical', 1249),
#  ('handle', 1248),
#  ('deal', 1240),
#  ('discover', 1226),
#  ('storage', 1225),
#  ('focus', 1219),
#  ('people', 1218),
#  ('willingness', 1211),
#  ('others', 1204),
#  ('public', 1184),
#  ('internet', 1174),
#  ('cross', 1172),
#  ('comfortable', 1165),
#  ('vision', 1163),
#  ('hand', 1163),
#  ('supply', 1145),
#  ('defining', 1145),
#  ('invent', 1144),
#  ('changing', 1139),
#  ('processing', 1134),
#  ('job', 1133),
#  ('value', 1130),
#  ('consumer', 1125),
#  ('travel', 1120),
#  ('unit', 1116),
#  ('statistical', 1115),
#  ('problemsolving', 1114),
#  ('university', 1113),
#  ('analyze', 1111),
#  ('sound', 1110),
#  ('innovative', 1108),
#  ('critical', 1107),
#  ('know', 1106),
#  ('clearly', 1101),
#  ('object', 1101),
#  ('html', 1099),
#  ('tableau', 1098),
#  ('compliance', 1082),
#  ('ec', 1082),
#  ('successful', 1073),
#  ('supporting', 1071),
#  ('superior', 1067),
#  ('higher', 1067),
#  ('thinking', 1056),
#  ('actual', 1056),
#  ('making', 1051),
#  ('bias', 1045),
#  ('recommendation', 1042),
#  ('optimization', 1036),
#  ('economics', 1031),
#  ('variety', 1027),
#  ('history', 1021),
#  ('execution', 1020),
#  ('ordinance', 1016),
#  ('scalability', 1012),
#  ('test', 1007),
#  ('driven', 1005),
#  ('challenge', 1005),
#  ('broad', 1002),
#  ('pursuant', 1000),
#  ('training', 994),
#  ('extensive', 993),
#  ('articulate', 993),
#  ('device', 987),
#  ('content', 987),
#  ('personal', 986),
#  ('maintaining', 983),
#  ('hiring', 982),
#  ('hnd', 981),
#  ('provide', 981),
#  ('preferably', 980),
#  ('significant', 972),
#  ('honed', 961),
#  ('top', 959),
#  ('http', 953),
#  ('capability', 950),
#  ('responsibility', 939),
#  ('following', 939),
#  ('medium', 937),
#  ('hadoop', 937),
#  ('write', 936),
#  ('leader', 934),
#  ('architecting', 933),
#  ('expert', 930),
#  ('digital', 922),
#  ('sigma', 922),
#  ('flexible', 920),
#  ('arrest', 917),
#  ('desired', 915),
#  ('shift', 913),
#  ('adapt', 909),
#  ('mining', 906),
#  ('improve', 905),
#  ('demonstrate', 903),
#  ('recruiting', 901),
#  ('chain', 894),
#  ('hardware', 891),
#  ('may', 887),
#  ('accounting', 887),
#  ('issue', 881),
#  ('sense', 879),
#  ('every', 878),
#  ('query', 877),
#  ('international', 876),
#  ('intelligence', 867),
#  ('retail', 865),
#  ('logistics', 863),
#  ('fluent', 863),
#  ('part', 859),
#  ('accredited', 858),
#  ('employment', 857),
#  ('interface', 855),
#  ('learn', 854),
#  ('workload', 853),
#  ('commercial', 853),
#  ('scoping', 851),
#  ('please', 845),
#  ('tuning', 845),
#  ('cs', 843),
#  ('active', 841),
#  ('window', 840),
#  ('member', 831),
#  ('chance', 831),
#  ('right', 816),
#  ('executing', 816),
#  ('strategic', 814),
#  ('interest', 812),
#  ('group', 809),
#  ('scrum', 809),
#  ('spark', 808),
#  ('fluency', 807),
#  ('without', 805),
#  ('human', 800),
#  ('lifecycle', 798),
#  ('automated', 796),
#  ('insight', 794),
#  ('diverse', 789),
#  ('thrive', 786),
#  ('hr', 785),
#  ('balancing', 785),
#  ('launch', 783),
#  ('relational', 775),
#  ('back', 774),
#  ('regarding', 771),
#  ('common', 770),
#  ('workflow', 770),
#  ('manufacturing', 764),
#  ('idea', 762),
#  ('end', 761),
#  ('outlook', 756),
#  ('exposure', 754),
#  ('graduate', 753),
#  ('also', 753),
#  ('desire', 751),
#  ('availability', 750),
#  ('function', 748),
#  ('analytic', 746),
#  ('visualization', 746),
#  ('report', 746),
#  ('deployment', 745),
#  ('react', 744),
#  ('market', 744),
#  ('conviction', 743),
#  ('creative', 742),
#  ('dns', 742),
#  ('comfort', 734),
#  ('believe', 734),
#  ('execute', 734),
#  ('creating', 733),
#  ('done', 732),
#  ('vendor', 731),
#  ('junior', 726),
#  ('school', 725),
#  ('multitask', 720),
#  ('collect', 718),
#  ('initiative', 717),
#  ('key', 713),
#  ('requires', 713),
#  ('acumen', 710),
#  ('startup', 707),
#  ('negotiation', 707),
#  ('warehousing', 704),
#  ('architect', 701),
#  ('engagement', 698),
#  ('thing', 697),
#  ('simplify', 697),
#  ('different', 695),
#  ('various', 692),
#  ('customerfacing', 690),
#  ('fair', 685),
#  ('would', 682),
#  ('monitoring', 680),
#  ('advertising', 679),
#  ('demonstrable', 675),
#  ('volume', 674),
#  ('individual', 673),
#  ('analyzing', 673),
#  ('backend', 672),
#  ('setting', 669),
#  ('willing', 669),
#  ('tight', 667),
#  ('simultaneously', 662),
#  ('implement', 661),
#  ('two', 658),
#  ('go', 655),
#  ('frontend', 654),
#  ('sleeve', 653),
#  ('handling', 649),
#  ('configuration', 647),
#  ('purpose', 646),
#  ('prioritization', 646),
#  ('apply', 646),
#  ('domain', 644),
#  ('lean', 643),
#  ('nosql', 641),
#  ('tcp', 641),
#  ('major', 638),
#  ('hnc', 637),
#  ('architectural', 636),
#  ('describe', 636),
#  ('android', 636),
#  ('peer', 628),
#  ('ml', 628),
#  ('directly', 625),
#  ('effort', 622),
#  ('bash', 619),
#  ('corporate', 613),
#  ('scala', 613),
#  ('honestly', 609),
#  ('concise', 609),
#  ('health', 609),
#  ('associate', 607),
#  ('rest', 607),
#  ('distribution', 606),
#  ('open', 606),
#  ('outstanding', 603),
#  ('access', 602),
#  ('visit', 602),
#  ('francisco', 602),
#  ('passionate', 600),
#  ('ip', 599),
#  ('search', 595),
#  ('experienced', 592),
#  ('completion', 591),
#  ('community', 588),
#  ('mi', 588),
#  ('multitiered', 586),
#  ('career', 583),
#  ('forecasting', 583),
#  ('offer', 579),
#  ('houston', 577),
#  ('housing', 577),
#  ('roll', 576),
#  ('cause', 574),
#  ('datasets', 572),
#  ('method', 569),
#  ('direction', 568),
#  ('presenting', 568),
#  ('document', 567),
#  ('country', 565),
#  ('applying', 565),
#  ('mechanical', 565),
#  ('qualified', 563),
#  ('documentation', 563),
#  ('proactive', 562),
#  ('tracking', 562),
#  ('consider', 561),
#  ('hard', 559),
#  ('include', 559),
#  ('manner', 558),
#  ('selling', 558),
#  ('discussion', 556),
#  ('dynamodb', 553),
#  ('benefit', 552),
#  ('ecosystem', 552),
#  ('familiar', 551),
#  ('player', 551),
#  ('mission', 550),
#  ('prioritizing', 549),
#  ('housekeeping', 548),
#  ('stack', 548),
#  ('study', 548),
#  ('powerpoint', 547),
#  ('root', 546),
#  ('sdlc', 546),
#  ('motivated', 544),
#  ('deliverable', 543),
#  ('get', 543),
#  ('trade', 543),
#  ('core', 543),
#  ('nodejs', 543),
#  ('range', 542),
#  ('release', 541),
#  ('race', 540),
#  ('point', 540),
#  ('flexibility', 539),
#  ('order', 538),
#  ('equipment', 537),
#  ('great', 535),
#  ('hour', 535),
#  ('household', 534),
#  ('government', 533),
#  ('appropriate', 532),
#  ('six', 532),
#  ('provider', 531),
#  ('dealing', 529),
#  ('mentor', 529),
#  ('how', 528),
#  ('needed', 528),
#  ('potential', 527),
#  ('performing', 526),
#  ('disparate', 526),
#  ('detailed', 524),
#  ('rapidly', 524),
#  ('necessary', 518),
#  ('interaction', 517),
#  ('detailoriented', 516),
#  ('space', 515),
#  ('suite', 514),
#  ('day', 514),
#  ('redshift', 514),
#  ('law', 512),
#  ('either', 512),
#  ('spanish', 507),
#  ('debugging', 506),
#  ('supervision', 504),
#  ('package', 504),
#  ('case', 503),
#  ('challenging', 503),
#  ('industrial', 501),
#  ('outcome', 500),
#  ('night', 500),
#  ('intermediate', 499),
#  ('personnel', 496),
#  ('puppet', 496),
#  ('type', 495),
#  ('hipaa', 495),
#  ('combination', 494),
#  ('partnership', 492),
#  ('serviceoriented', 492),
#  ('interview', 491),
#  ('natural', 491),
#  ('diploma', 490),
#  ('en', 488),
#  ('weekend', 487),
#  ('entrepreneurial', 487),
#  ('commitment', 485),
#  ('mysql', 485),
#  ('towards', 483),
#  ('identify', 482),
#  ('warehouse', 481),
#  ('complete', 481),
#  ('bring', 479),
#  ('operate', 479),
#  ('shipping', 477),
#  ('state', 475),
#  ('however', 473),
#  ('aggressive', 472),
#  ('objective', 471),
#  ('certified', 470),
#  ('request', 468),
#  ('ci', 467),
#  ('powershell', 464),
#  ('capacity', 463),
#  ('facing', 463),
#  ('io', 463),
#  ('house', 462),
#  ('tech', 462),
#  ('wide', 461),
#  ('agency', 461),
#  ('around', 461),
#  ('spring', 460),
#  ('measure', 459),
#  ('contact', 458),
#  ('create', 458),
#  ('strategically', 456),
#  ('line', 456),
#  ('closely', 456),
#  ('firm', 455),
#  ('authorize', 455),
#  ('innovation', 454),
#  ('selfstarter', 453),
#  ('iterative', 453),
#  ('german', 452),
#  ('crossfunctionally', 452),
#  ('conducting', 452),
#  ('owner', 451),
#  ('worldwide', 450),
#  ('ux', 449),
#  ('demonstrating', 448),
#  ('capable', 448),
#  ('hp', 447),
#  ('competitive', 446),
#  ('attitude', 445),
#  ('talent', 445),
#  ('party', 445),
#  ('power', 445),
#  ('datadriven', 443),
#  ('load', 443),
#  ('faulttolerant', 443),
#  ('undefined', 442),
#  ('shell', 442),
#  ('present', 441),
#  ('procedure', 439),
#  ('motivate', 438),
#  ('sourcing', 438),
#  ('hive', 437),
#  ('proactively', 435),
#  ('long', 433),
#  ('adoption', 433),
#  ('act', 431),
#  ('meeting', 430),
#  ('past', 430),
#  ('event', 428),
#  ('religion', 428),
#  ('component', 428),
#  ('define', 425),
#  ('robust', 425),
#  ('compensation', 424),
#  ('see', 423),
#  ('typically', 423),
#  ('general', 420),
#  ('base', 418),
#  ('you', 417),
#  ('exhibit', 417),
#  ('highperformance', 416),
#  ('ad', 415),
#  ('apis', 415),
#  ('video', 414),
#  ('segment', 414),
#  ('cloudformation', 414),
#  ('ranging', 413),
#  ('matlab', 413),
#  ('howto', 411),
#  ('positive', 410),
#  ('activity', 410),
#  ('honesty', 409),
#  ('rds', 408),
#  ('efficiency', 407),
#  ('aptitude', 407),
#  ('ie', 406),
#  ('selfmotivated', 406),
#  ('resolve', 406),
#  ('growth', 406),
#  ('regulation', 406),
#  ('bi', 405),
#  ('oo', 405),
#  ('help', 404),
#  ('outside', 403),
#  ('scope', 403),
#  ('status', 402),
#  ('national', 401),
#  ('maintenance', 401),
#  ('evidence', 401),
#  ('routing', 401),
#  ('pivot', 400),
#  ('coordinating', 399),
#  ('protection', 397),
#  ('expectation', 396),
#  ('kaizen', 395),
#  ('clearance', 395),
#  ('japanese', 395),
#  ('small', 394),
#  ('evaluate', 394),
#  ('virtualization', 394),
#  ('prototype', 394),
#  ('managed', 392),
#  ('embedded', 392),
#  ('relation', 390),
#  ('collaborative', 389),
#  ('scientist', 387),
#  ('policy', 386),
#  ('clevel', 386),
#  ('saas', 386),
#  ('ideally', 384),
#  ('demand', 384),
#  ('salesforce', 383),
#  ('apache', 383),
#  ('location', 382),
#  ('multitasking', 381),
#  ('evaluating', 381),
#  ('french', 380),
#  ('negotiating', 380),
#  ('skilled', 380),
#  ('overall', 379),
#  ('für', 378),
#  ('coaching', 378),
#  ('table', 377),
#  ('stretch', 377),
#  ('sector', 376),
#  ('extremely', 375),
#  ('engage', 375),
#  ('speaking', 375),
#  ('situation', 373),
#  ('contract', 373),
#  ('api', 372),
#  ('topic', 370),
#  ('lab', 370),
#  ('advantage', 367),
#  ('autonomously', 367),
#  ('accuracy', 365),
#  ('analyst', 365),
#  ('trust', 365),
#  ('san', 365),
#  ('hmms', 364),
#  ('require', 363),
#  ('several', 363),
#  ('tactically', 361),
#  ('formal', 361),
#  ('collaboration', 359),
#  ('du', 359),
#  ('recommend', 359),
#  ('crm', 358),
#  ('brand', 358),
#  ('site', 357),
#  ('inventory', 357),
#  ('dive', 356),
#  ('matter', 356),
#  ('endtoend', 356),
#  ('longterm', 356),
#  ('roadmap', 355),
#  ('culture', 353),
#  ('physic', 353),
#  ('underlying', 353),
#  ('scheduling', 352),
#  ('native', 351),
#  ('demonstrates', 349),
#  ('question', 349),
#  ('transportation', 349),
#  ('channel', 349),
#  ('cd', 349),
#  ('resolution', 349),
#  ('way', 347),
#  ('month', 346),
#  ('partnering', 345),
#  ('call', 345),
#  ('local', 345),
#  ('electronics', 344),
#  ('teamwork', 344),
#  ('sharp', 344),
#  ('emr', 343),
#  ('legacy', 341),
#  ('effectiveness', 341),
#  ('serverless', 341),
#  ('opensource', 341),
#  ('limited', 340),
#  ('even', 340),
#  ('structured', 340),
#  ('selfdirected', 338),
#  ('lambda', 338),
#  ('enjoy', 337),
#  ('simple', 337),
#  ('internship', 337),
#  ('thought', 337),
#  ('forward', 337),
#  ('belief', 336),
#  ('cost', 336),
#  ('tactical', 336),
#  ('publication', 336),
#  ('efficient', 336),
#  ('longstanding', 335),
#  ('library', 335),
#  ('zum', 333),
#  ('target', 333),
#  ('procurement', 332),
#  ('mitigation', 332),
#  ('dem', 331),
#  ('indepth', 331),
#  ('selected', 330),
#  ('front', 328),
#  ('visual', 328),
#  ('progressive', 327),
#  ('werden', 327),
#  ('durch', 327),
#  ('scientific', 327),
#  ('exceed', 326),
#  ('involving', 326),
#  ('app', 325),
#  ('comprehensive', 324),
#  ('etl', 324),
#  ('offering', 323),
#  ('existing', 323),
#  ('timeline', 323),
#  ('optimal', 323),
#  ('multithreaded', 323),
#  ('response', 322),
#  ('focused', 322),
#  ('notice', 320),
#  ('ihrer', 320),
#  ('used', 320),
#  ('term', 318),
#  ('optimizing', 318),
#  ('decisionmaking', 317),
#  ('listening', 317),
#  ('los', 316),
#  ('season', 316),
#  ('ibm', 315),
#  ('engaging', 314),
#  ('bb', 314),
#  ('campaign', 314),
#  ('accommodation', 314),
#  ('along', 313),
#  ('subject', 313),
#  ('hire', 312),
#  ('feasibility', 312),
#  ('submitting', 312),
#  ('five', 311),
#  ('guidance', 311),
#  ('exceeding', 311),
#  ('secure', 311),
#  ('additional', 311),
#  ('sa', 310),
#  ('currently', 309),
#  ('deploying', 309),
#  ('custom', 309),
#  ('email', 308),
#  ('da', 308),
#  ('minimal', 307),
#  ('particularly', 306),
#  ('world', 305),
#  ('usability', 305),
#  ('qa', 305),
#  ('protecting', 303),
#  ('true', 303),
#  ('awsamazoncom', 302),
#  ('organized', 301),
#  ('le', 300),
#  ('alternative', 300),
#  ('committed', 300),
#  ('definition', 300),
#  ('conception', 298),
#  ('primary', 297),
#  ('includes', 297),
#  ('workable', 297),
#  ('competency', 296),
#  ('assurance', 296),
#  ('houdini', 295),
#  ('internals', 295),
#  ('spoken', 294),
#  ('designer', 294),
#  ('stock', 294),
#  ('virtual', 294),
#  ('pipeline', 293),
#  ('compute', 293),
#  ('ui', 293),
#  ('low', 292),
#  ('finding', 292),
#  ('display', 291),
#  ('humor', 289),
#  ('physical', 289),
#  ('utilizing', 288),
#  ('consult', 288),
#  ('einstellenden', 287),
#  ('webbased', 287),
#  ('itil', 286),
#  ('italian', 285),
#  ('number', 285),
#  ('directory', 285),
#  ('thorough', 284),
#  ('awareness', 283),
#  ('predictive', 282),
#  ('driver', 281),
#  ('look', 281),
#  ('engine', 281),
#  ('prototyping', 281),
#  ('theory', 280),
#  ('salesforcecom', 280),
#  ('third', 280),
#  ('assessment', 279),
#  ('actionable', 279),
#  ('authorized', 279),
#  ('unternehmen', 278),
#  ('tier', 278),
#  ('vba', 277),
#  ('growing', 277),
#  ('speech', 276),
#  ('running', 276),
#  ('discus', 276),
#  ('selfmotivate', 275),
#  ('specific', 275),
#  ('concisely', 275),
#  ('exploring', 275),
#  ('balance', 274),
#  ('evolving', 274),
#  ('inc', 273),
#  ('store', 273),
#  ('highlyavailable', 272),
#  ('respect', 271),
#  ('motivating', 271),
#  ('honeywell', 270),
#  ('desirable', 270),
#  ('quicksight', 270),
#  ('addition', 270),
#  ('integrity', 269),
#  ('command', 269),
#  ('bar', 269),
#  ('confidentiality', 269),
#  ('pl', 269),
#  ('recent', 268),
#  ('sap', 268),
#  ('contribution', 268),
#  ('et', 267),
#  ('future', 266),
#  ('jquery', 266),
#  ('confidential', 265),
#  ('technically', 264),
#  ('determine', 264),
#  ('pressure', 263),
#  ('landscape', 263),
#  ...]

# %%
from wordcloud import WordCloud, STOPWORDS
dummyt = ' '.join(words)

# %%
wordcloud = WordCloud(relative_scaling = 1.0, max_words = 80, background_color = "white",\
                     colormap = "Dark2").generate(dummyt)

# %%
def plot_wordcloud(wordcloud):
    plt.figure(figsize=(15,12))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
plot_wordcloud(wordcloud)
